# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression, RidgeCV, LassoCV, ElasticNetCV, RANSACRegressor, HuberRegressor
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# Só vamos usar nesse notebook os dados escalonados

# %%
df = pd.read_csv('./melting-point/train_scaled.csv')

# %%
melting_point={}
melting_point["data"] = df.drop(['Tm'], axis=1).values
melting_point["target"] = df["Tm"].values

# %%
X_train, X_test, Y_train, Y_test = train_test_split(melting_point["data"], melting_point["target"], test_size=0.1)

# %% [markdown]
# # Regressor Linear

# %%
lr = LinearRegression()

lr.fit(X_train, Y_train)
pred = lr.predict(X_test)

print("R2 score:", lr.score(X_test, Y_test))
print("Mean Absolute error:", mean_absolute_error(Y_test, pred))
# Out:
# R2 score: 0.41100966378607684
# Mean Absolute error: 41.33075484007815

# %%
plt.plot(Y_test, c='blue')
plt.plot(pred, c='red')

plt.show()

# %%
lr_scores = cross_val_score(lr, melting_point["data"], melting_point["target"], cv=10, scoring='neg_mean_absolute_error')
print(lr_scores)
print(lr_scores.mean())
print(lr_scores.std())
# Out:
# [-38.52529129 -36.39924098 -38.52384631 -34.96310041 -38.64937435
#  -38.87804474 -38.06550993 -37.16309176 -38.64136337 -34.85893073]
# -37.46677938539316
# 1.4719820636831384

# %% [markdown]
# # Ridge Regression

# %%
rg = RidgeCV(alphas=(1000.0, 100.0, 50.0, 10.0, 5.0, 4.0, 3.0, 2.0, 1.0, 0.1, 0.01, 0.05, 0.005, 0.0025, 0.001, 0.00025), cv=10)

rg.fit(X_train, Y_train)
pred = rg.predict(X_test)

print(rg.alpha_)
print("R2 score:", rg.score(X_test, Y_test))
print("Mean Absolute error:", mean_absolute_error(Y_test, pred))
# Out:
# 100.0
# R2 score: 0.42725959464889585
# Mean Absolute error: 41.132003396946274

# %%
plt.plot(Y_test, c='blue')
plt.plot(pred, c='red')

plt.show()

# %%
rg_scores = cross_val_score(rg, melting_point['data'], melting_point['target'], cv=10, scoring="neg_mean_absolute_error")
print(rg_scores)
print(rg_scores.mean())
print(rg_scores.std())
# Out:
# [-39.07994924 -36.9710957  -38.439493   -34.62990191 -37.85156718
#  -38.40704975 -39.06710646 -37.43117512 -38.67093626 -33.92344789]
# -37.44717225141152
# 1.7157475553736714

# %% [markdown]
# # Lasso Regression

# %%
ls = LassoCV(alphas=(1000.0, 100.0, 50.0, 10.0, 5.0, 4.0, 3.0, 2.0, 1.0, 0.1, 0.01, 0.005, 0.0025, 0.001, 0.00025), cv=10, max_iter=10000)

ls.fit(X_train, Y_train)
pred = ls.predict(X_test)

print(ls.alpha_)
print("R2 score:", ls.score(X_test, Y_test))
print("Mean Absolute error:", mean_absolute_error(Y_test, pred))
# Out:
# 0.1
# R2 score: 0.42447517145980584
# Mean Absolute error: 41.142200237929615

# %%
plt.plot(Y_test, c='blue')
plt.plot(pred, c='red')

plt.show()

# %%
ls_scores = cross_val_score(ls, melting_point['data'], melting_point['target'], cv=10, scoring='neg_mean_absolute_error')
print(ls_scores)
print(ls_scores.mean())
print(ls_scores.std())
# Out:
# [-38.19520191 -36.2989122  -38.29972193 -34.47940868 -38.0700577
#  -38.38284355 -38.39907357 -37.12113236 -38.5298131  -34.17210257]
# -37.1948267562573
# 1.579550771338198

# %% [markdown]
# # Elastic Net

# %%
encv = ElasticNetCV(alphas=(1000.0, 100.0, 50.0, 10.0, 5.0, 4.0, 3.0, 2.0, 1.0, 0.1, 0.01, 0.005, 0.0025, 0.001, 0.00025), l1_ratio=(0.1, 0.25, 0.5, 0.75, 0.8, 0.9, 1),cv=10, max_iter=10000)

encv.fit(X_train, Y_train)
pred = encv.predict(X_test)

print(encv.alpha_)
print(encv.l1_ratio_)
print("R2 score:", encv.score(X_test, Y_test))
print("Mean Absolute error:", mean_absolute_error(Y_test, pred))
# Out:
# D:\puc\ml\venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.568e+03, tolerance: 1.533e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\puc\ml\venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.203e+03, tolerance: 1.592e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# 0.1
# 0.75
# R2 score: 0.43024665891879155
# Mean Absolute error: 41.087408349116394

# %%
plt.plot(Y_test, c='blue')
plt.plot(pred, c='red')

plt.show()

# %%
encv_scores = cross_val_score(encv, melting_point['data'], melting_point['target'], cv=10, scoring='neg_mean_absolute_error')
print(encv_scores)
print(encv_scores.mean())
print(encv_scores.std())
# Out:
# D:\puc\ml\venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.601e+03, tolerance: 1.537e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\puc\ml\venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.645e+03, tolerance: 1.560e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\puc\ml\venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.773e+03, tolerance: 1.570e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\puc\ml\venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.582e+03, tolerance: 1.549e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\puc\ml\venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.055e+03, tolerance: 1.572e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\puc\ml\venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.029e+03, tolerance: 1.551e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\puc\ml\venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.270e+03, tolerance: 1.580e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\puc\ml\venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.568e+03, tolerance: 1.565e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\puc\ml\venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.600e+03, tolerance: 1.578e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\puc\ml\venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.037e+03, tolerance: 1.569e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\puc\ml\venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.029e+03, tolerance: 1.597e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\puc\ml\venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.442e+03, tolerance: 1.564e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\puc\ml\venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.790e+03, tolerance: 1.590e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\puc\ml\venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.288e+03, tolerance: 1.558e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\puc\ml\venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.017e+03, tolerance: 1.563e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\puc\ml\venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.438e+03, tolerance: 1.564e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\puc\ml\venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.579e+03, tolerance: 1.557e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# D:\puc\ml\venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.158e+03, tolerance: 1.597e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# [-38.87109322 -36.76822141 -38.29303719 -34.41231267 -37.77460253
#  -38.18944771 -38.87175645 -37.68329139 -38.56905523 -33.88329307]
# -37.33161108768913
# 1.7024709566381693

# %% [markdown]
# # RANSAC

# %%
rs = RANSACRegressor()

rs.fit(X_train, Y_train)
pred = rs.predict(X_test)

print("R2 score:", rs.score(X_test, Y_test))
print("Mean Absolute error:", mean_absolute_error(Y_test, pred))
# Out:
# R2 score: 0.271787602702378
# Mean Absolute error: 46.96582373262509

# %%
plt.plot(Y_test, c='blue')
plt.plot(pred, c='red')

plt.show()

# %%
rs_scores = cross_val_score(rs, melting_point['data'], melting_point['target'], cv=10, scoring='neg_mean_absolute_error')
print(rs_scores)
print(rs_scores.mean())
print(rs_scores.std())
# Out:
# [-46.9788748  -41.75573321 -47.65393016 -43.39056634 -53.03059641
#  -42.73506971 -48.61350085 -44.84957065 -44.62962368 -40.92941203]
# -45.456687784227675
# 3.4841995857469983

# %% [markdown]
# # Huber Regression

# %%
hr = HuberRegressor(epsilon=2.0, max_iter=1000)

hr.fit(X_train, Y_train)
pred = hr.predict(X_test)

print("R2 score:", hr.score(X_test, Y_test))
print("Mean Absolute error:", mean_absolute_error(Y_test, pred))
# Out:
# R2 score: 0.0788373688563575
# Mean Absolute error: 44.46957057673014

# %%
plt.plot(Y_test, c='blue')
plt.plot(pred, c='red')

plt.show()

# %%
hr_scores = cross_val_score(hr, melting_point['data'], melting_point['target'], cv=10, scoring='neg_mean_absolute_error')
print(hr_scores)
print(hr_scores.mean())
print(hr_scores.std())
# Out:
# [-41.78862026 -43.5832977  -42.09975573 -38.11961418 -42.19497316
#  -42.40985452 -49.51246312 -42.53519086 -40.50153502 -40.30246138]
# -42.30477659306622
# 2.806181246375621

# %% [markdown]
# # Leaderboard

# %%
modelos = {
    "Regressor Linear": lr_scores,
    "Ridge": rg_scores,
    "Lasso": ls_scores,
    "ElasticNet": encv_scores,
    "RANSAC": rs_scores,
    "Huber": hr_scores
}

# %%
resultados = []
for nome, score in modelos.items():
    resultados.append({
        "Modelo": nome,
        "Média do Score": score.mean(),
        "Desvio Padrão": score.std()
    })

leaderboard = pd.DataFrame(resultados).sort_values(by="Média do Score", ascending=False)
leaderboard.reset_index(drop=True, inplace=True)

display(leaderboard.style.background_gradient(cmap="Greens").format({"Média do Score": "{:.4f}", "Desvio Padrão": "{:.4f}"}))
# Out:
# <style type="text/css">
# #T_54544_row0_col1, #T_54544_row5_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_54544_row0_col2 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_54544_row1_col1 {
#   background-color: #00491d;
#   color: #f1f1f1;
# }
# #T_54544_row1_col2 {
#   background-color: #e7f6e2;
#   color: #000000;
# }
# #T_54544_row2_col1 {
#   background-color: #004d1f;
#   color: #f1f1f1;
# }
# #T_54544_row2_col2 {
#   background-color: #e5f5e1;
#   color: #000000;
# }
# #T_54544_row3_col1 {
#   background-color: #004e1f;
#   color: #f1f1f1;
# }
# #T_54544_row3_col2, #T_54544_row5_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_54544_row4_col1 {
#   background-color: #9fd899;
#   color: #000000;
# }
# #T_54544_row4_col2 {
#   background-color: #38a156;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_54544">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_54544_level0_col0" class="col_heading level0 col0" >Modelo</th>
#       <th id="T_54544_level0_col1" class="col_heading level0 col1" >Média do Score</th>
#       <th id="T_54544_level0_col2" class="col_heading level0 col2" >Desvio Padrão</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_54544_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_54544_row0_col0" class="data row0 col0" >Lasso</td>
#       <td id="T_54544_row0_col1" class="data row0 col1" >-37.1948</td>
#       <td id="T_54544_row0_col2" class="data row0 col2" >1.5796</td>
#     </tr>
#     <tr>
#       <th id="T_54544_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_54544_row1_col0" class="data row1 col0" >ElasticNet</td>
#       <td id="T_54544_row1_col1" class="data row1 col1" >-37.3316</td>
#       <td id="T_54544_row1_col2" class="data row1 col2" >1.7025</td>
#     </tr>
#     <tr>
#       <th id="T_54544_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_54544_row2_col0" class="data row2 col0" >Ridge</td>
#       <td id="T_54544_row2_col1" class="data row2 col1" >-37.4472</td>
#       <td id="T_54544_row2_col2" class="data row2 col2" >1.7157</td>
#     </tr>
#     <tr>
#       <th id="T_54544_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_54544_row3_col0" class="data row3 col0" >Regressor Linear</td>
#       <td id="T_54544_row3_col1" class="data row3 col1" >-37.4668</td>
#       <td id="T_54544_row3_col2" class="data row3 col2" >1.4720</td>
#     </tr>
#     <tr>
#       <th id="T_54544_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_54544_row4_col0" class="data row4 col0" >Huber</td>
#       <td id="T_54544_row4_col1" class="data row4 col1" >-42.3048</td>
#       <td id="T_54544_row4_col2" class="data row4 col2" >2.8062</td>
#     </tr>
#     <tr>
#       <th id="T_54544_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_54544_row5_col0" class="data row5 col0" >RANSAC</td>
#       <td id="T_54544_row5_col1" class="data row5 col1" >-45.4567</td>
#       <td id="T_54544_row5_col2" class="data row5 col2" >3.4842</td>
#     </tr>
#   </tbody>
# </table>
